# %%
score = [90, 80, 88, 84, 85, 87, 88, 89, 90, 100]
score[0] = score[0]+10
score[9] = score[9]-10
print('更新後分數', score)
# Out:
# 更新後分數 [100, 80, 88, 84, 85, 87, 88, 89, 90, 90]

# %%
score = []
print('目前串列內容 = ',score)
score.append('80')
print('目前串列內容 = ',score)
score.append('80')
print('目前串列內容 = ',score)
score.append('80')
print('目前串列內容 = ',score)
